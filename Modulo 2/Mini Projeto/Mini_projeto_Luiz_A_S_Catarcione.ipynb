# %% [markdown]
# ## Mini Projeto 1
# <br>
# Você trabalha em uma Rede Social e precisa criar uma estrutura que represente as pessoas que a usam em python (com Programação Orientado a Objetos).
# <br>
# É necessário guardar informações das pessoas que utilizam essa rede social:
#
# * nome
# * apelido
# * data de nascimento
# * e-mail
# * amigos
# * lista de interesses
# * posts
# Adicional:
# * melhores amigos
# <br>
#
# E além disso, existem algumas funcionalidades que precisamos ter:
# * adicionar um amigo na lista de amigos
# * adicionar um interesse na lista interesses
# * postar
# * calcular a quantidade de amigos
# * calcular a quantidade de posts
# * dado um nome, verificar se existe um amigo ou melhor amigo com esse nome (e retornar esses amigos, se existirem)
# * dado uma palavra ou frase, trazer TODOS os posts com aquela palavra (procurar post)
# * ~~mostrar os posts dos amigos~~
# Adicional:
# * transformar um amigo em melhor amigo
# * mostrar os posts
#      * melhores amigos primeiro
#      * amigos depois
# * desfazer amizade
# * bloquear (não permitir que a amizade com determinada pessoa seja efetuada)
# ---
# Parâmetros de correção:
# * Documentação
# * Bom nomes de classe, atributos, métodos, etc.
# * Lógica
# ---
# É importante que você traga os testes que fez para testar as funcionalidades!

# %%
class Usuario:
    def __init__(self, nome, apelido, nascimento, email, amigos = None):
  
      '''
      cria uma representação da entidade Rede Social = Usuario

      Parametros
      ----------
      nome : str
        Nome da pessoa 
      apelido  : str
        apelido da pessoa 
      nascimento : str
        data de nascimento
      email : str
        e-mail da pessoa

      '''
# criando os meus atributos
      self.nome = nome
      self.apelido = apelido
      self.nascimento = nascimento
      self.email = email

# criando os meus atributos não vinculados ao construtor
      self.amigos = []
      self.interesse = []
      self.post = []
      self.nome = nome
      if(amigos is None):
            self.amigos = []
    
    def adicionar_amigo(self, amigo):
      '''
      Adionando um amigo a lista de amigos
      Parâmetros
      ----------
      amigo : str
         amigo a ser adicionado
      Retorno
      ---------- 
      self.amigo : list
        retorna e exibe a lista com o acrescimo do novo amigo
      '''
      # adiciona um amigo a lista de amigos
      self.amigos.append(amigo) 
      # retorna a exibição da lista alterada
      return print("A lista de amigos é:",self.amigos)

    def adicionar_interesse(self, interesse):
      '''
      Adiciona interesse a lista de interesses
      Parâmetros
      ----------
      interesse : str
         interesse a ser adicionado
      Retorno
      ---------- 
      self.interesse : list
        retorna e exibe a lista com o acrescimo do novo interesse
      '''
      # acrescenta um novo interesse a lsita de interesses
      self.interesse.append(interesse) 
      # retorna e exibe a lista de interesses
      return print("A lista de interesses é:", self.interesse)

    def postar(self, post):
      '''
      Adiona um post a lista de posts e exibe-o
      Parâmetros
      ----------
      post : str
         post a ser exibido
      Retorno
      ---------- 
      self.post : str
        retorna a exibição lista com o acrescimo do novo posts
      '''
      # acrescenta um post a lista de posts
      self.post.append(post) 
      # retorna e exibe a lista de posts acrescentada
      return print("A lista de posts é:", self.post)
    
    def calcular_numero_amigos(self):
      '''
      Calcula o numero de amigos de um usuário
      Parâmetros
      ----------
      self : list
         lista de amigos
      Retorno
      ---------- 
      self.amigos : int
        retorna e exibe o numero de amigos 
      '''
      # Calcula o numero de amigos
      numero_amigos = len(self.amigos) 
      # Retorna e exibe o numero de amigos
      return print(" A quantidade de amigos é: ",numero_amigos)
      
    def calcular_numero_posts(self):
      '''
      Calcula o numero de posts de um usuário
      Parâmetros
      ----------
      self : list
         lista de posts
      Retorno
      ---------- 
      self.post : int
        retorna o numero de posts 
      '''
      # calcula aquantidade de posts de um usuário
      numero_post = len(self.post) 
      # Retorna e exibe a quantidade de postes
      return print(" A quantidade de posts é: ", numero_post)

    def buscar_nome(self, nome):
      '''
      Busca o nome e verifica se existe um amigo ou melhor amigo com esse nome
      Parâmetros
      ----------
      busca : str
         nome a ser procurado
      Retorno
      ---------- 
      self.busca : list
        retorna alista com os nomes de amigo, dado um nome específico 
      '''
      # idetifica a quantidade de nomesna lista. Caso não haja amigos, retorna
      # com mensagem de aviso de lista vazia
      resultado_amigo = []
      if len(self.amigos) == 0:
        print("Você não possui amigos")
      # permite que a pessoa seja achada com parte de seu nome, não precisando 
      # digitar o nome completo   
      else:
        for amigo in self.amigos:
          palavras_de_cada_amigo = amigo.split()
          palavras_de_busca = nome.split()
          if any([palavra in palavras_de_cada_amigo for palavra in palavras_de_busca]):
             print(amigo)
             #print(resultado_amigo.append(amigo))
          #else:
        #if amigo == []:
        #  print("Não existe", nome, "como amigo")
        #else:
        # print("Os amigos são", amigo)
    
    def procurar_post(self, frase):
      '''
      Dado uma palavra ou frase, trazer TODOS os posts com aquela palavra
      Parâmetros
      ----------
      frase : str
         nome ou frase a ser procurado
      Retorno
      ---------- 
      post_achado : list
        retorna o print da lista com dos posts encontrados 
      
      '''
      post_achado = []
      if len(self.post) == 0:
        print("Você não possui posts")
      else:
        for post in self.post:
        #  separa cada post em string de palavras    
            palavras_de_cada_post = post.split()
        #  separa a frase a ser buscada em strings de palavras
            palavras_de_busca = frase.split()
        #  compara as strings e caso encontrada as palavras buscadas, 
        #  a palavra é armazenada em uma lista para depois ser exibida  
            for palavra1 in palavras_de_cada_post:
                for palavra2 in palavras_de_busca:
                    if palavra1 == palavra2:
                      post_achado.append(post)
        if post_achado == []:
          print("Não existe", frase, "em nenhum post")
        else: 
          return print("A lista com a frase'",frase,"'é:", post_achado)                    
      
luiz = Usuario('Luiz Maria','Lu', '11/06/66','a@e')
livia = Usuario('Livia Maria', 'Li','01/01/01','s@s')
mario = Usuario('Mario Livia', 'Ma', '01/01/02', 'm@m')
joao = Usuario('Joao Luiz', 'Jl', '01/01/03', 'j@j')
luiz.amigos
luiz.adicionar_amigo(livia.nome)
luiz.adicionar_amigo(mario.nome)
luiz.adicionar_amigo(joao.nome)
livia.amigos
luiz.interesse
luiz.adicionar_interesse("ler")
luiz.adicionar_interesse("estudar")
luiz.interesse
luiz.post = ["oi", "oi bom dia", "bom dia como vai", "ola", "bom dia"]
#mario.post = ["q legal", "oi"]
#livia.post = ["ola"]
luiz.postar("tudo bem")
luiz.postar("ola")
luiz.post
luiz.calcular_numero_amigos()
luiz.calcular_numero_posts()
luiz.buscar_nome("Livia")
luiz.procurar_post("bom")
# Out:
# A lista de amigos é: ['Livia Maria']
# A lista de amigos é: ['Livia Maria', 'Mario Livia']
# A lista de amigos é: ['Livia Maria', 'Mario Livia', 'Joao Luiz']
# A lista de interesses é: ['ler']
# A lista de interesses é: ['ler', 'estudar']
# A lista de posts é: ['oi', 'oi bom dia', 'bom dia como vai', 'ola', 'bom dia', 'tudo bem']
# A lista de posts é: ['oi', 'oi bom dia', 'bom dia como vai', 'ola', 'bom dia', 'tudo bem', 'ola']
#  A quantidade de amigos é:  3
#  A quantidade de posts é:  7
# Livia Maria
# Mario Livia
# A lista com a frase' bom 'é: ['oi bom dia', 'bom dia como vai', 'bom dia']
